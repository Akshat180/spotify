# %% [markdown]
# # Data Dictionary

# %% [markdown]
# - `acousticness:` A measure of the acoustic characteristics of a song, ranging from 0 to 1.
# - `danceability:` A measure of how suitable a track is for dancing, ranging from 0 to 1.
# - `duration_ms:` The duration of the song in milliseconds.
# - `energy:` Represents the energy of the song, ranging from 0 to 1.
# - `instrumentalness:` Indicates the likelihood of the song containing no vocals, ranging from 0 to 1.
# - `key:` Represents the key of the track.
# - `liveness:` Indicates the presence of a live audience in the recording, ranging from 0 to 1.
# - `loudness:` Represents the overall loudness of the track in decibels (dB).
# - `mode:` Indicates the modality of the track, where 0 represents minor and 1 represents major.
# - `speechiness:` Represents the presence of spoken words in the track, ranging from 0 to 1.
# - `tempo:` Represents the tempo of the track in beats per minute (BPM).
# - `time_signature:` Represents the time signature of the track.
# - `valence:` Represents the musical positiveness conveyed by the track, ranging from 0 to 1.
# - `target:` Indicates whether the track is a hit or not (1 for hit, 0 for not hit).
# - `song_title:` The title of the song.
# - `artist:` The name of the artist who performed the song.

# %% [markdown]
# # Task

# %% [markdown]
# - [x] Top 5 most popular artists
# - [x] Top 5 loudest tracks
# - [x] Artist with the most danceability song
# - [x] To 10 instrumentalness tracks
# - [x] Overall distribution of continuous data variables
# - [x] Top 10 energetic tracks
# - [x] Most common durations
# - [x] Top  10 tracks with the most valence
# - [x] Most popular artist

# %% [markdown]
# <a id="import"></a>
# # <p style="background-color:lightblue; font-family:calibri; color:white; font-size:150%; text-align:center; border-radius:15px 50px;">Step 1 | Import Libraries</p>

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %% [markdown]
# <a id="read"></a>
# # <p style="background-color:lightblue ; font-family:calibri; color:white; font-size:150%; text-align:center; border-radius:15px 50px;">Step 2 | Read Dataset</p>

# %%
df = pd.read_csv(r'C:\Users\Kunwa\OneDrive\Desktop\Data Science\Data Science Course Project\Data\spotify\data.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'acousticness', 'danceability', 'duration_ms', 'energy',
#        'instrumentalness', 'key', 'liveness', 'loudness', 'mode',
#        'speechiness', 'tempo', 'time_signature', 'valence', 'target',
#        'song_title', 'artist'],
#       dtype='object')

# %%
df.head(10)
# Out:
#    Unnamed: 0  acousticness  danceability  duration_ms  energy
# 0           0       0.01020         0.833       204600   0.434  \
# 1           1       0.19900         0.743       326933   0.359
# 2           2       0.03440         0.838       185707   0.412
# 3           3       0.60400         0.494       199413   0.338
# 4           4       0.18000         0.678       392893   0.561
# 5           5       0.00479         0.804       251333   0.560
# 6           6       0.01450         0.739       241400   0.472
# 7           7       0.02020         0.266       349667   0.348
# 8           8       0.04810         0.603       202853   0.944
# 9           9       0.00208         0.836       226840   0.603
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo
# 0          0.021900    2    0.1650    -8.795     1       0.4310  150.062  \
# 1          0.006110    1    0.1370   -10.401     1       0.0794  160.083
# ...

# %% [markdown]
# ### Removing extra column name Unnamed: 0

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)
df.head()
# Out:
#    acousticness  danceability  duration_ms  energy  instrumentalness  key
# 0        0.0102         0.833       204600   0.434          0.021900    2  \
# 1        0.1990         0.743       326933   0.359          0.006110    1
# 2        0.0344         0.838       185707   0.412          0.000234    2
# 3        0.6040         0.494       199413   0.338          0.510000    5
# 4        0.1800         0.678       392893   0.561          0.512000    5
#
#    liveness  loudness  mode  speechiness    tempo  time_signature  valence
# 0    0.1650    -8.795     1       0.4310  150.062             4.0    0.286  \
# 1    0.1370   -10.401     1       0.0794  160.083             4.0    0.588
# 2    0.1590    -7.148     1       0.2890   75.044             4.0    0.173
# 3    0.0922   -15.236     1       0.0261   86.468             4.0    0.230
# 4    0.4390   -11.648     0       0.0694  174.004             4.0    0.904
#
#    target      song_title            artist
# ...

# %% [markdown]
# <a id="read"></a>
# # <p style="background-color:lightblue ; font-family:calibri; color:white; font-size:150%; text-align:center; border-radius:15px 50px;">Step 3 | Data Cleaning</p>

# %% [markdown]
# ## Step 3.1 | Checking missing values in the dataset

# %%
df.isna().sum()
# Out:
# acousticness        0
# danceability        0
# duration_ms         0
# energy              0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# speechiness         0
# tempo               0
# time_signature      0
# valence             0
# target              0
# song_title          0
# artist              0
# dtype: int64

# %% [markdown]
# ## Step 3.2 | Dataset Basic Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2017 entries, 0 to 2016
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   acousticness      2017 non-null   float64
#  1   danceability      2017 non-null   float64
#  2   duration_ms       2017 non-null   int64
#  3   energy            2017 non-null   float64
#  4   instrumentalness  2017 non-null   float64
#  5   key               2017 non-null   int64
#  6   liveness          2017 non-null   float64
#  7   loudness          2017 non-null   float64
#  8   mode              2017 non-null   int64
#  9   speechiness       2017 non-null   float64
#  10  tempo             2017 non-null   float64
#  11  time_signature    2017 non-null   float64
#  12  valence           2017 non-null   float64
#  13  target            2017 non-null   int64
#  14  song_title        2017 non-null   object
#  15  artist            2017 non-null   object
# ...

# %%
df.shape
# Out:
# (2017, 16)

# %%
df.columns.nunique()
# Out:
# 16

# %% [markdown]
# ## Step 3.3 | Summary Statistics for Numerical Variables

# %%
df.describe().T
# Out:
#                    count           mean           std           min
# acousticness      2017.0       0.187590      0.259989      0.000003  \
# danceability      2017.0       0.618422      0.161029      0.122000
# duration_ms       2017.0  246306.197323  81981.814219  16042.000000
# energy            2017.0       0.681577      0.210273      0.014800
# instrumentalness  2017.0       0.133286      0.273162      0.000000
# key               2017.0       5.342588      3.648240      0.000000
# liveness          2017.0       0.190844      0.155453      0.018800
# loudness          2017.0      -7.085624      3.761684    -33.097000
# mode              2017.0       0.612295      0.487347      0.000000
# speechiness       2017.0       0.092664      0.089931      0.023100
# tempo             2017.0     121.603272     26.685604     47.859000
# time_signature    2017.0       3.968270      0.255853      1.000000
# valence           2017.0       0.496815      0.247195      0.034800
# ...

# %% [markdown]
# <a id="eda"></a>
# # <p style="background-color:lightblue; font-family:calibri; color:white; font-size:150%; text-align:center; border-radius:15px 50px;">Step 4 | EDA</p>

# %% [markdown]
# ## Top 5 most popular artists

# %%
top_five_artists = df.groupby('artist').count().sort_values(by='song_title',ascending=False)
t5 = top_five_artists['song_title'].head()
t5
# Out:
# artist
# Drake              16
# Rick Ross          13
# Disclosure         12
# Backstreet Boys    10
# WALK THE MOON      10
# Name: song_title, dtype: int64

# %%
t5.plot(kind='pie',autopct ='%.2f%%',ylabel='Top 5 Artist',title='Top 5 most popular artists')
# Out:
# <Axes: title={'center': 'Top 5 most popular artists'}, ylabel='Top 5 Artist'>

# %%
plt.figure(figsize=(5,2))
t5.plot.barh()
plt.xlabel('Song Title')
plt.title('Top 5 most popular artists')
plt.show()

# %% [markdown]
# ## Top 5 loudest tracks

# %%
Top_five_Lt = df[['loudness', 'song_title']].sort_values(by='loudness',ascending=True).head()
Top_five_Lt
# Out:
#       loudness                                         song_title
# 1594   -33.097            Lyric Pieces, Book I Op. 12: I. Arietta
# 1596   -31.367            8 Fantasiestücke, Op.12 : 1. Des Abends
# 1598   -31.082  Piano Quartet in E flat, Op.47: 3. Andante can...
# 1531   -30.447          I Was So Young, and You Were So Beautiful
# 1549   -29.460                                            Eleanor

# %%
plt.figure(figsize=(5,2))
graph =sns.barplot(x='loudness',y='song_title',data=Top_five_Lt)
graph.set( ylabel = "Songs", title ='Top 5 loudest tracks')
# Out:
# [Text(0, 0.5, 'Songs'), Text(0.5, 1.0, 'Top 5 loudest tracks')]

# %% [markdown]
# ##  Artist with the most danceability song

# %%
t5_ads = df[['danceability','song_title','artist']].sort_values(by='danceability',ascending = False).head()
t5_ads
# Out:
#       danceability              song_title             artist
# 1433         0.984  Flashwind - Radio Edit       Ben Remember
# 1901         0.967                SexyBack  Justin Timberlake
# 604          0.962       Check Me Out Like          Blaqstarr
# 32           0.959             Best Friend         Young Thug
# 1957         0.959            Ice Ice Baby        Vanilla Ice

# %%
plt.figure(figsize=(8,4))
sns.barplot(data=t5_ads, x='artist', y="danceability",hue='song_title')
plt.title('Artist with the most danceability song')
plt.xlabel('Artist')
plt.legend(bbox_to_anchor=(1.05,1), loc=2, borderaxespad=1,title='Songs title')
plt.show()

# %% [markdown]
# ## Top 10 instrumentalness tracks

# %%
t5_It = df[['instrumentalness','song_title','artist']].sort_values(by='instrumentalness',ascending = False).head()
t5_It
# Out:
#       instrumentalness                            song_title
# 1313             0.976                       Senseless Order  \
# 271              0.968  So Destroyed (channeling Rage Peace)
# 1575             0.964             A Hundred Dreams from Now
# 1619             0.958                                 Raven
# 725              0.957                     Strandbar (disko)
#
#                   artist
# 1313  Signs of the Swarm
# 271          Prince Rama
# 1575          Ray Bryant
# 1619       John Dahlbäck
# 725           Todd Terje

# %%
plt.figure(figsize=(8,4))
plt.pie(data=t5_It, x='instrumentalness',autopct = '%.2f%%',labels=t5_It['song_title'])
plt.title('Top 10 instrumentalness tracks')
plt.show()

# %% [markdown]
# ##  Overall distribution of continuous data variables

# %%
features = ['tempo','loudness','acousticness','danceability','duration_ms','energy',
            'instrumentalness','liveness','speechiness','valence']

# %%
for x in features:
    pos_data = df[df['target'] == 1][x]
    neg_data = df[df['target'] == 0][x]
    plt.figure(figsize=(12,7))
    
    sns.histplot(pos_data, bins=30,label='Positive',color='green',kde=True)
    sns.histplot(neg_data,bins=30,label='Negative',color='red',kde=True)
    plt.legend(loc='upper right')
    plt.title(f'Positive and Negative Histogram Plot for {x}')
    plt.show()

# %%
df.head()
# Out:
#    acousticness  danceability  duration_ms  energy  instrumentalness  key
# 0        0.0102         0.833       204600   0.434          0.021900    2  \
# 1        0.1990         0.743       326933   0.359          0.006110    1
# 2        0.0344         0.838       185707   0.412          0.000234    2
# 3        0.6040         0.494       199413   0.338          0.510000    5
# 4        0.1800         0.678       392893   0.561          0.512000    5
#
#    liveness  loudness  mode  speechiness    tempo  time_signature  valence
# 0    0.1650    -8.795     1       0.4310  150.062             4.0    0.286  \
# 1    0.1370   -10.401     1       0.0794  160.083             4.0    0.588
# 2    0.1590    -7.148     1       0.2890   75.044             4.0    0.173
# 3    0.0922   -15.236     1       0.0261   86.468             4.0    0.230
# 4    0.4390   -11.648     0       0.0694  174.004             4.0    0.904
#
#    target      song_title            artist
# ...

# %% [markdown]
# ## Top 10 energetic tracks

# %%
energy_Song = df[['energy','song_title','artist']].sort_values(by='energy',ascending = False).head(10)
energy_Song
# Out:
#       energy           song_title                    artist
# 1299   0.998        No Absolution         Thy Art Is Murder
# 1322   0.997           Pitchblack  Walking Dead On Broadway
# 1297   0.994    A Darkened Gospel      A Wake in Providence
# 1347   0.993           Unanswered           Suicide Silence
# 2015   0.992        First Contact                Twin Moons
# 1680   0.992             Paranoia         A Day To Remember
# 1332   0.992      Beautiful Agony          Within The Ruins
# 1328   0.991  Down into the Abyss               Conjonctive
# 1681   0.990                Hated                 Beartooth
# 1296   0.990         Black Colors       Victim Of Deception

# %%
plt.figure(figsize=(10,5))
plt.pie(data=energy_Song, x='energy',autopct = '%.2f%%',labels=energy_Song['song_title'])
plt.title('Top 10 energetic tracks')
plt.show()

# %% [markdown]
# ## Most common durations Songs

# %%
common_duration = df['duration_ms'].value_counts()
print('Top 5',common_duration.head())
# Out:
# Top 5 duration_ms
# 192000    5
# 243493    3
# 206013    3
# 228467    3
# 240000    3
# Name: count, dtype: int64

# %%
list_of_songs_in_Particular_duration = {}
for i in list(common_duration.head().keys()):
    songs_list = list(df[df['duration_ms'] == i]['song_title'])
    list_of_songs_in_Particular_duration.update({i:songs_list})

# %%
print('list of songs top 5 duration\n',list_of_songs_in_Particular_duration)
# Out:
# list of songs top 5 duration
#  {192000: ['Kerosene', 'How Not To', 'White Label (Is This Love)', 'Milky Way', 'Shape of You (Major Lazer Remix) [feat. Nyla & Kranium]'], 243493: ['God Must Have Spent a Little More Time on You - Remix', 'Fantasy', 'Das Lied Der Schluempfe'], 206013: ['Summer Night You and I', 'I Dare You', 'Hey Baby - Steve Aoki Remix'], 228467: ['I Follow Rivers', 'Traicionera', 'Something To Believe In'], 240000: ['Stoner', 'Bailame Despacio', 'Aquaman']}

# %% [markdown]
# ## Top 10 tracks with the most valence1

# %%
t10_It = df[['valence','song_title']].sort_values(by='valence',ascending = False).head(10)
t10_It
# Out:
#       valence                                         song_title
# 460     0.992                             Abataka - Original Mix
# 912     0.975                I'm Walkin' - 2002 Digital Remaster
# 1966    0.974        To Roz Bikini (Itsy, Bitsy, Teenie, Weenie)
# 207     0.973                                        Look at You
# 48      0.973                              Azon de ma gnin kpevi
# 337     0.972  Let's Lovedance Tonight - Danny Krivit Re-edit...
# 1590    0.972                                   Jelly On A Plate
# 838     0.971  Let's Lovedance Tonight - Danny Krivit Re-edit...
# 497     0.968                               Mi Swing es Tropical
# 112     0.967                                 Please Mr. Postman

# %%
sns.lineplot(x = 'valence', y = 'song_title', data = t10_It)
plt.ylabel('Song title')
plt.xticks(rotation=45)
plt.title('Top 10 tracks with the most valence1')
plt.show()

# %% [markdown]
# ### Most popular artist

# %%
df.head()
# Out:
#    acousticness  danceability  duration_ms  energy  instrumentalness  key
# 0        0.0102         0.833       204600   0.434          0.021900    2  \
# 1        0.1990         0.743       326933   0.359          0.006110    1
# 2        0.0344         0.838       185707   0.412          0.000234    2
# 3        0.6040         0.494       199413   0.338          0.510000    5
# 4        0.1800         0.678       392893   0.561          0.512000    5
#
#    liveness  loudness  mode  speechiness    tempo  time_signature  valence
# 0    0.1650    -8.795     1       0.4310  150.062             4.0    0.286  \
# 1    0.1370   -10.401     1       0.0794  160.083             4.0    0.588
# 2    0.1590    -7.148     1       0.2890   75.044             4.0    0.173
# 3    0.0922   -15.236     1       0.0261   86.468             4.0    0.230
# 4    0.4390   -11.648     0       0.0694  174.004             4.0    0.904
#
#    target      song_title            artist
# ...

# %%
df['time_signature'].unique()
# Out:
# array([4., 3., 5., 1.])

# %%
continuous_features = df.select_dtypes(include='number')
sns.set_palette(['#b3cee5', 'red'])

# Create the subplots
fig, ax = plt.subplots(len(continuous_features.columns), 2, figsize=(25, 25), gridspec_kw={'width_ratios': [1, 2]})

# Loop through each continuous feature to create barplots and kde plots
for i, col in enumerate(continuous_features):
    # Barplot showing the mean value of the feature for each target category
    graph = sns.barplot(data=df, x="target", y=col, ax=ax[i, 0])
    
    # KDE plot showing the distribution of the feature for each target category
    sns.kdeplot(data=df[df["target"]==0], x=col, fill=True, linewidth=2, ax=ax[i, 1], label='0')
    sns.kdeplot(data=df[df["target"]==1], x=col, color='red', fill=True, linewidth=2, ax=ax[i, 1], label='1')
    ax[i, 1].set_yticks([])
    ax[i, 1].legend(title='Heart Disease', loc='upper right')
    
    # Add mean values to the barplot
    for cont in graph.containers:
        graph.bar_label(cont, fmt='%.3g')
        
# Set the title for the entire figure
plt.suptitle('Continuous Features vs Target Distribution', fontsize=22)
plt.tight_layout()                     
plt.show()
# Out:
# C:\Users\Kunwa\AppData\Local\Temp\ipykernel_21400\236390875.py:13: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(data=df[df["target"]==0], x=col, fill=True, linewidth=2, ax=ax[i, 1], label='0')
# C:\Users\Kunwa\AppData\Local\Temp\ipykernel_21400\236390875.py:14: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(data=df[df["target"]==1], x=col, color='red', fill=True, linewidth=2, ax=ax[i, 1], label='1')
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # Conclusion
# These data visualizations aid in understanding the factors contributing to a song's success, denoted by a "hit" label (1) in the target variable. By analyzing the distribution of variables, we can discern that certain characteristics are indicative of a hit song.
